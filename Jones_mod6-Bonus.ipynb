# %%
import csv
import pandas as pd

# %%
teams = pd.read_csv("https://raw.githubusercontent.com/leesharpe/nfldata/master/data/teams.csv")

# %%
teams
# Out:
#      season team  nfl  nfl_team_id espn  pfr   pff pfflabel   fo  \
# 0      2002  ARI  ARI         3800  ARI  CRD   NaN      NaN  ARI
# 1      2002  ATL  ATL          200  ATL  ATL   NaN      NaN  ATL
# 2      2002  BAL  BAL          325  BAL  RAV   NaN      NaN  BAL
# 3      2002  BUF  BUF          610  BUF  BUF   NaN      NaN  BUF
# 4      2002  CAR  CAR          750  CAR  CAR   NaN      NaN  CAR
# ..      ...  ...  ...          ...  ...  ...   ...      ...  ...
# 667    2022  SEA  SEA         4600  SEA  SEA  29.0      SEA  SEA
# 668    2022   SF   SF         4500   SF  SFO  28.0       SF   SF
# 669    2022   TB   TB         4900   TB  TAM  30.0       TB   TB
# 670    2022  TEN  TEN         2100  TEN  OTI  31.0      TEN  TEN
# 671    2022  WAS  WAS         5110  WSH  WAS  32.0      WAS  WAS
#
#                       full       location short_location    nickname  \
# 0        Arizona Cardinals        Arizona        Arizona   Cardinals
# 1          Atlanta Falcons        Atlanta        Atlanta     Falcons
# 2         Baltimore Ravens      Baltimore      Baltimore      Ravens
# 3            Buffalo Bills        Buffalo        Buffalo       Bills
# 4        Carolina Panthers       Carolina       Carolina    Panthers
# ..                     ...            ...            ...         ...
# 667       Seattle Seahawks        Seattle        Seattle    Seahawks
# 668    San Francisco 49ers  San Francisco  San Francisco       49ers
# 669   Tampa Bay Buccaneers      Tampa Bay      Tampa Bay  Buccaneers
# 670       Tennessee Titans      Tennessee      Tennessee      Titans
# 671  Washington Commanders     Washington     Washington  Commanders
#
#                 hyphenated   sbr  sbr_wins               sbr_name  \
# 0        arizona-cardinals  1549       NaN                    NaN
# 1          atlanta-falcons  1546       NaN                    NaN
# 2         baltimore-ravens  1521       NaN                    NaN
# 3            buffalo-bills  1526       NaN                    NaN
# 4        carolina-panthers  1545       NaN                    NaN
# ..                     ...   ...       ...                    ...
# 667       seattle-seahawks  1548       NaN       Seattle Seahawks
# 668    san-francisco-49ers  1547       NaN    San Francisco 49ers
# 669   tampa-bay-buccaneers  1544       NaN   Tampa Bay Buccaneers
# 670       tennessee-titans  1528       NaN       Tennessee Titans
# 671  washington-commanders  1537       NaN  Washington Commanders
#
#         draft_kings
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 667    SEA Seahawks
# 668        SF 49ers
# 669   TB Buccaneers
# 670      TEN Titans
# 671  WAS Commanders
#
# [672 rows x 18 columns]

# %%
teams.rename(columns={"location": "City", "full": "Full Name"})
# Out:
#      season team  nfl  nfl_team_id espn  pfr   pff pfflabel   fo  \
# 0      2002  ARI  ARI         3800  ARI  CRD   NaN      NaN  ARI
# 1      2002  ATL  ATL          200  ATL  ATL   NaN      NaN  ATL
# 2      2002  BAL  BAL          325  BAL  RAV   NaN      NaN  BAL
# 3      2002  BUF  BUF          610  BUF  BUF   NaN      NaN  BUF
# 4      2002  CAR  CAR          750  CAR  CAR   NaN      NaN  CAR
# ..      ...  ...  ...          ...  ...  ...   ...      ...  ...
# 667    2022  SEA  SEA         4600  SEA  SEA  29.0      SEA  SEA
# 668    2022   SF   SF         4500   SF  SFO  28.0       SF   SF
# 669    2022   TB   TB         4900   TB  TAM  30.0       TB   TB
# 670    2022  TEN  TEN         2100  TEN  OTI  31.0      TEN  TEN
# 671    2022  WAS  WAS         5110  WSH  WAS  32.0      WAS  WAS
#
#                  Full Name           City short_location    nickname  \
# 0        Arizona Cardinals        Arizona        Arizona   Cardinals
# 1          Atlanta Falcons        Atlanta        Atlanta     Falcons
# 2         Baltimore Ravens      Baltimore      Baltimore      Ravens
# 3            Buffalo Bills        Buffalo        Buffalo       Bills
# 4        Carolina Panthers       Carolina       Carolina    Panthers
# ..                     ...            ...            ...         ...
# 667       Seattle Seahawks        Seattle        Seattle    Seahawks
# 668    San Francisco 49ers  San Francisco  San Francisco       49ers
# 669   Tampa Bay Buccaneers      Tampa Bay      Tampa Bay  Buccaneers
# 670       Tennessee Titans      Tennessee      Tennessee      Titans
# 671  Washington Commanders     Washington     Washington  Commanders
#
#                 hyphenated   sbr  sbr_wins               sbr_name  \
# 0        arizona-cardinals  1549       NaN                    NaN
# 1          atlanta-falcons  1546       NaN                    NaN
# 2         baltimore-ravens  1521       NaN                    NaN
# 3            buffalo-bills  1526       NaN                    NaN
# 4        carolina-panthers  1545       NaN                    NaN
# ..                     ...   ...       ...                    ...
# 667       seattle-seahawks  1548       NaN       Seattle Seahawks
# 668    san-francisco-49ers  1547       NaN    San Francisco 49ers
# 669   tampa-bay-buccaneers  1544       NaN   Tampa Bay Buccaneers
# 670       tennessee-titans  1528       NaN       Tennessee Titans
# 671  washington-commanders  1537       NaN  Washington Commanders
#
#         draft_kings
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 667    SEA Seahawks
# 668        SF 49ers
# 669   TB Buccaneers
# 670      TEN Titans
# 671  WAS Commanders
#
# [672 rows x 18 columns]

# %%
pd.set_option('display.precision', 2)

# %%
teams.describe()
# Out:
#         season  nfl_team_id     pff       sbr  sbr_wins
# count   672.00       672.00  544.00    672.00  3.20e+01
# mean   2012.00      2517.66   16.50   2193.86  4.08e+06
# std       6.06      1389.61    9.24   6951.70  2.07e+03
# min    2002.00       200.00    1.00   1519.00  4.08e+06
# 25%    2007.00      1350.00    8.75   1526.75  4.08e+06
# 50%    2012.00      2410.00   16.50   1535.00  4.08e+06
# 75%    2017.00      3497.50   24.25   1543.00  4.08e+06
# max    2022.00      5110.00   32.00  75380.00  4.09e+06

# %%
teams.hist()
# Out:
# array([[<AxesSubplot:title={'center':'season'}>,
#         <AxesSubplot:title={'center':'nfl_team_id'}>],
#        [<AxesSubplot:title={'center':'pff'}>,
#         <AxesSubplot:title={'center':'sbr'}>],
#        [<AxesSubplot:title={'center':'sbr_wins'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
teams['team'].unique()
# Out:
# array(['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL',
#        'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'MIA', 'MIN', 'NE',
#        'NO', 'NYG', 'NYJ', 'OAK', 'PHI', 'PIT', 'SD', 'SEA', 'SF', 'STL',
#        'TB', 'TEN', 'WAS', 'LA', 'LAC', 'LV'], dtype=object)

# %%
teams.query("team == 'KC'")
# Out:
#      season team nfl  nfl_team_id espn  pfr   pff pfflabel  fo  \
# 15     2002   KC  KC         2310   KC  KAN   NaN      NaN  KC
# 47     2003   KC  KC         2310   KC  KAN   NaN      NaN  KC
# 79     2004   KC  KC         2310   KC  KAN   NaN      NaN  KC
# 111    2005   KC  KC         2310   KC  KAN   NaN      NaN  KC
# 143    2006   KC  KC         2310   KC  KAN  16.0       KC  KC
# 175    2007   KC  KC         2310   KC  KAN  16.0       KC  KC
# 207    2008   KC  KC         2310   KC  KAN  16.0       KC  KC
# 239    2009   KC  KC         2310   KC  KAN  16.0       KC  KC
# 271    2010   KC  KC         2310   KC  KAN  16.0       KC  KC
# 303    2011   KC  KC         2310   KC  KAN  16.0       KC  KC
# 335    2012   KC  KC         2310   KC  KAN  16.0       KC  KC
# 367    2013   KC  KC         2310   KC  KAN  16.0       KC  KC
# 399    2014   KC  KC         2310   KC  KAN  16.0       KC  KC
# 431    2015   KC  KC         2310   KC  KAN  16.0       KC  KC
# 463    2016   KC  KC         2310   KC  KAN  16.0       KC  KC
# 495    2017   KC  KC         2310   KC  KAN  16.0       KC  KC
# 527    2018   KC  KC         2310   KC  KAN  16.0       KC  KC
# 559    2019   KC  KC         2310   KC  KAN  16.0       KC  KC
# 591    2020   KC  KC         2310   KC  KAN  16.0       KC  KC
# 623    2021   KC  KC         2310   KC  KAN  16.0       KC  KC
# 655    2022   KC  KC         2310   KC  KAN  16.0       KC  KC
#
#                    full     location short_location nickname  \
# 15   Kansas City Chiefs  Kansas City    Kansas City   Chiefs
# 47   Kansas City Chiefs  Kansas City    Kansas City   Chiefs
# 79   Kansas City Chiefs  Kansas City    Kansas City   Chiefs
